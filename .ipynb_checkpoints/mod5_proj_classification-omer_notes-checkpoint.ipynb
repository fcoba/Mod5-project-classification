# %% [markdown]
# # Mod 5 Project: Classifying Life Expectancy (World Health Organization Data)

# %% [markdown]
# **Group Partners: Filis, Manisha, Pablo**
#
# ___

# %% [markdown]
# Ran the following commands in terminal to install Profiling (visualizing data), and Altair (map):
#
# ```
# conda install -c conda-forge altair vega_datasets notebook vega
# ```
#
# ```
# conda install -c anaconda pandas-profiling
# ```

# %% [markdown]
# ### Import libraries

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/ff/75/3982bac5076d0ce6d23103c03840fcaec90c533409f9d82c19f54512a38a/plotly-3.10.0-py2.py3-none-any.whl (41.5MB)
#     100% |████████████████████████████████| 41.5MB 391kB/s ta 0:00:011
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from plotly) (2.21.0)
# Requirement already satisfied: decorator>=4.0.6 in /anaconda3/lib/python3.7/site-packages (from plotly) (4.3.0)
# Requirement already satisfied: pytz in /anaconda3/lib/python3.7/site-packages (from plotly) (2018.7)
# Requirement already satisfied: nbformat>=4.2 in /anaconda3/lib/python3.7/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)
# Collecting retrying>=1.3.3 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (2018.11.29)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: ipython-genutils in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: jupyter-core in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Building wheels for collected packages: retrying
#   Running setup.py bdist_wheel for retrying ... done
#   Stored in directory: /Users/buddy4732/Library/Caches/pip/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# Installing collected packages: retrying, plotly

# %%
import pandas as pd  
import numpy as np

import plotly.plotly as py 
import plotly 
import cufflinks as cf 
import pandas as pd 
import numpy as np 

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True) 
cf.go_offline()


#Making Visualizations
import altair as alt
alt.renderers.enable('notebook')
from vega_datasets import data

#Displaying EDA Profile
import pandas_profiling

#Disabling warnings 
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b97d0ca029be> in <module>
#       2 import numpy as np
#       3
# ----> 4 import plotly.plotly as py
#       5 import plotly
#       6 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ### Read in csv and display first few rows

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Seeing if data is time series

# %%
df_group = df.set_index(['Country','Year'])
df_group.head()
# Out:
#                       Status  Life expectancy   Adult Mortality  \
# Country     Year
# Afghanistan 2015  Developing              65.0            263.0
#             2014  Developing              59.9            271.0
#             2013  Developing              59.9            268.0
#             2012  Developing              59.5            272.0
#             2011  Developing              59.2            275.0
#
#                   infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country     Year
# Afghanistan 2015             62     0.01               71.279624         65.0
#             2014             64     0.01               73.523582         62.0
#             2013             66     0.01               73.219243         64.0
#             2012             69     0.01               78.184215         67.0
#             2011             71     0.01                7.097109         68.0
#
#                   Measles    BMI   under-five deaths   Polio  \
# Country     Year
# Afghanistan 2015      1154   19.1                  83    6.0
#             2014       492   18.6                  86   58.0
#             2013       430   18.1                  89   62.0
#             2012      2787   17.6                  93   67.0
#             2011      3013   17.2                  97   68.0
#
#                   Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# Country     Year
# Afghanistan 2015               8.16         65.0        0.1  584.259210
#             2014               8.18         62.0        0.1  612.696514
#             2013               8.13         64.0        0.1  631.744976
#             2012               8.52         67.0        0.1  669.959000
#             2011               7.87         68.0        0.1   63.537231
#
#                   Population   thinness  1-19 years   thinness 5-9 years  \
# Country     Year
# Afghanistan 2015  33736494.0                   17.2                 17.3
#             2014    327582.0                   17.5                 17.5
#             2013  31731688.0                   17.7                 17.7
#             2012   3696958.0                   17.9                 18.0
#             2011   2978599.0                   18.2                 18.2
#
#                   Income composition of resources  Schooling
# Country     Year
# Afghanistan 2015                            0.479       10.1
#             2014                            0.476       10.0
#             2013                            0.470        9.9
#             2012                            0.463        9.8
#             2011                            0.454        9.5

# %%
countries = df['Country'].unique()
for country in countries:
    df_group.loc[country].iplot(y='Life expectancy ')
    print(country)
# Out:
# <div>
#
#
#             <div id="37204e71-ca45-47dd-9f61-de1b196af12d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("37204e71-ca45-47dd-9f61-de1b196af12d")) {
#                     Plotly.newPlot(
#                         '37204e71-ca45-47dd-9f61-de1b196af12d',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "e4126a76-dd0f-4948-8d90-71b235cc1a21", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [65.0, 59.9, 59.9, 59.5, 59.2, 58.8, 58.6, 58.1, 57.5, 57.3, 57.3, 57.0, 56.7, 56.2, 55.3, 54.8]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('37204e71-ca45-47dd-9f61-de1b196af12d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Afghanistan
# <div>
#
#
#             <div id="7b38445d-0def-4ba0-8de0-e3d0ccf23d65" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7b38445d-0def-4ba0-8de0-e3d0ccf23d65")) {
#                     Plotly.newPlot(
#                         '7b38445d-0def-4ba0-8de0-e3d0ccf23d65',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "7244f5ce-374c-4ad8-977e-5138de4bf97c", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [77.8, 77.5, 77.2, 76.9, 76.6, 76.2, 76.1, 75.3, 75.9, 74.2, 73.5, 73.0, 72.8, 73.3, 73.6, 72.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7b38445d-0def-4ba0-8de0-e3d0ccf23d65');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Albania
# <div>
#
#
#             <div id="cc44daec-e304-466f-bae3-735e2f27711f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cc44daec-e304-466f-bae3-735e2f27711f")) {
#                     Plotly.newPlot(
#                         'cc44daec-e304-466f-bae3-735e2f27711f',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "fb752937-1854-4438-9a50-ac97421c70d9", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [75.6, 75.4, 75.3, 75.1, 74.9, 74.7, 74.4, 74.1, 73.8, 73.4, 72.9, 72.3, 71.7, 71.6, 71.4, 71.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('cc44daec-e304-466f-bae3-735e2f27711f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Algeria
# <div>
#
#
#             <div id="869f1d29-0bea-4678-a2cd-581235857da7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("869f1d29-0bea-4678-a2cd-581235857da7")) {
#                     Plotly.newPlot(
#                         '869f1d29-0bea-4678-a2cd-581235857da7',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "e47fcbcb-6ef4-4922-b3ba-509d8ea46e0c", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [52.4, 51.7, 51.1, 56.0, 51.0, 49.6, 49.1, 48.7, 48.2, 47.7, 47.4, 47.1, 46.8, 46.5, 45.7, 45.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('869f1d29-0bea-4678-a2cd-581235857da7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Angola
# <div>
#
#
#             <div id="632b1fba-064a-4e24-8393-4ad8cee03cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("632b1fba-064a-4e24-8393-4ad8cee03cc7")) {
#                     Plotly.newPlot(
#                         '632b1fba-064a-4e24-8393-4ad8cee03cc7',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "e9ba326e-0692-43ff-b3ba-778132edf3c2", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.4, 76.2, 76.1, 75.9, 75.7, 75.6, 75.4, 75.2, 75.0, 74.8, 74.6, 74.4, 74.2, 74.0, 73.8, 73.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('632b1fba-064a-4e24-8393-4ad8cee03cc7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Antigua and Barbuda
# <div>
#
#
#             <div id="64c7083e-7f5e-4598-9f0b-a4f37d498b20" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("64c7083e-7f5e-4598-9f0b-a4f37d498b20")) {
#                     Plotly.newPlot(
#                         '64c7083e-7f5e-4598-9f0b-a4f37d498b20',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "2111774a-d082-46b9-b6f3-4a4ab02b250f", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.3, 76.2, 76.0, 75.9, 75.7, 75.5, 75.6, 75.4, 74.8, 75.2, 74.9, 74.7, 74.1, 74.1, 74.0, 74.1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('64c7083e-7f5e-4598-9f0b-a4f37d498b20');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Argentina
# <div>
#
#
#             <div id="4810394d-604b-4cc7-bc12-a2f2a7e1aa33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4810394d-604b-4cc7-bc12-a2f2a7e1aa33")) {
#                     Plotly.newPlot(
#                         '4810394d-604b-4cc7-bc12-a2f2a7e1aa33',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "36174600-386b-49c3-918a-a0d5b965440e", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [74.8, 74.6, 74.4, 74.4, 73.9, 73.5, 73.3, 73.2, 73.5, 72.9, 73.0, 73.0, 72.7, 72.6, 72.6, 72.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4810394d-604b-4cc7-bc12-a2f2a7e1aa33');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Armenia
# <div>
#
#
#             <div id="d011a26e-9d41-4d0e-b328-3b8e8599f9c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d011a26e-9d41-4d0e-b328-3b8e8599f9c7")) {
#                     Plotly.newPlot(
#                         'd011a26e-9d41-4d0e-b328-3b8e8599f9c7',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "5ea34b91-5696-4a8d-8406-04bf761c1a5f", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [82.8, 82.7, 82.5, 82.3, 82.0, 81.9, 81.7, 81.3, 81.3, 81.2, 81.0, 86.0, 83.0, 79.9, 79.9, 79.5]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d011a26e-9d41-4d0e-b328-3b8e8599f9c7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Australia
# <div>
#
#
#             <div id="75ce97e2-0432-43a9-b2b4-c50c11096b65" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("75ce97e2-0432-43a9-b2b4-c50c11096b65")) {
#                     Plotly.newPlot(
#                         '75ce97e2-0432-43a9-b2b4-c50c11096b65',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "8209b002-2252-49db-9478-cf7f0d324ceb", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [81.5, 81.4, 81.1, 88.0, 88.0, 84.0, 82.0, 84.0, 81.0, 79.8, 79.4, 79.3, 78.8, 78.7, 78.6, 78.1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('75ce97e2-0432-43a9-b2b4-c50c11096b65');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Austria
# <div>
#
#
#             <div id="d215baa3-c655-4303-8c5f-2143622752ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d215baa3-c655-4303-8c5f-2143622752ac")) {
#                     Plotly.newPlot(
#                         'd215baa3-c655-4303-8c5f-2143622752ac',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "1471bc1c-0c44-40e8-9162-f07ca73ff692", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [72.7, 72.5, 72.2, 71.9, 71.6, 71.1, 78.0, 73.0, 73.0, 69.2, 68.4, 68.4, 67.8, 67.8, 67.5, 66.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d215baa3-c655-4303-8c5f-2143622752ac');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Azerbaijan
# <div>
#
#
#             <div id="e28d6ed1-e968-4439-832e-393c7903153f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e28d6ed1-e968-4439-832e-393c7903153f")) {
#                     Plotly.newPlot(
#                         'e28d6ed1-e968-4439-832e-393c7903153f',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "30deeea3-e040-46da-bb1d-e61be61c0b2c", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.1, 75.4, 74.8, 74.9, 75.0, 75.0, 74.6, 74.5, 74.4, 74.2, 74.1, 73.8, 73.2, 73.1, 72.9, 72.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e28d6ed1-e968-4439-832e-393c7903153f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Bahamas
# <div>
#
#
#             <div id="91363054-2fd0-44bd-8792-1615734d45a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("91363054-2fd0-44bd-8792-1615734d45a6")) {
#                     Plotly.newPlot(
#                         '91363054-2fd0-44bd-8792-1615734d45a6',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "8d0b95be-8b67-4fd9-8ab9-8b97e0981262", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.9, 76.8, 76.7, 76.5, 76.1, 76.1, 76.0, 75.8, 75.6, 75.5, 75.3, 75.2, 75.0, 74.9, 74.7, 74.5]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('91363054-2fd0-44bd-8792-1615734d45a6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Bahrain
# <div>
#
#
#             <div id="e9123517-9a74-40ed-a017-046576217d0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9123517-9a74-40ed-a017-046576217d0f")) {
#                     Plotly.newPlot(
#                         'e9123517-9a74-40ed-a017-046576217d0f',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "e5d055c9-5c20-4c34-a913-d8a8f7e92d44", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [71.8, 71.4, 71.0, 77.0, 73.0, 69.9, 69.5, 69.1, 68.6, 68.2, 67.8, 67.3, 66.8, 66.3, 65.8, 65.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e9123517-9a74-40ed-a017-046576217d0f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Bangladesh
# <div>
#
#
#             <div id="34af6a9f-06ba-4772-a285-6c4940edc28b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("34af6a9f-06ba-4772-a285-6c4940edc28b")) {
#                     Plotly.newPlot(
#                         '34af6a9f-06ba-4772-a285-6c4940edc28b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "a25dd724-8e18-4402-bcb9-dbe19c90e455", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [75.5, 75.4, 75.2, 75.1, 74.9, 74.7, 74.6, 74.4, 74.2, 74.1, 73.9, 73.8, 73.7, 73.5, 73.4, 73.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('34af6a9f-06ba-4772-a285-6c4940edc28b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Barbados
# <div>
#
#
#             <div id="0eefe490-28ea-4c94-be03-4440a960db2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0eefe490-28ea-4c94-be03-4440a960db2e")) {
#                     Plotly.newPlot(
#                         '0eefe490-28ea-4c94-be03-4440a960db2e',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "071b6e49-b2f9-420b-bcc4-37c7106e77b4", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [72.3, 72.0, 71.7, 71.9, 72.0, 73.0, 70.0, 70.0, 69.8, 68.9, 68.1, 68.2, 67.7, 67.2, 67.7, 68.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0eefe490-28ea-4c94-be03-4440a960db2e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Belarus
# <div>
#
#
#             <div id="21421aa4-d4e6-421d-95a2-462ea8c574ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("21421aa4-d4e6-421d-95a2-462ea8c574ec")) {
#                     Plotly.newPlot(
#                         '21421aa4-d4e6-421d-95a2-462ea8c574ec',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "6db0e2ab-c9b6-4f61-a252-eacd0984faed", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [81.1, 89.0, 87.0, 83.0, 83.0, 80.0, 79.8, 79.5, 79.5, 79.4, 78.9, 78.8, 78.3, 78.0, 78.0, 77.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('21421aa4-d4e6-421d-95a2-462ea8c574ec');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Belgium
# <div>
#
#
#             <div id="9c79b326-24e9-4f61-8891-5fdbb5509920" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9c79b326-24e9-4f61-8891-5fdbb5509920")) {
#                     Plotly.newPlot(
#                         '9c79b326-24e9-4f61-8891-5fdbb5509920',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "34002c31-4302-499d-914d-9c6c867d772b", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [71.0, 70.0, 69.8, 69.4, 69.4, 69.5, 69.5, 69.6, 69.6, 69.4, 69.0, 68.7, 68.4, 68.5, 68.2, 68.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9c79b326-24e9-4f61-8891-5fdbb5509920');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Belize
# <div>
#
#
#             <div id="748066a2-594a-41e2-9955-ce9d248209ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("748066a2-594a-41e2-9955-ce9d248209ed")) {
#                     Plotly.newPlot(
#                         '748066a2-594a-41e2-9955-ce9d248209ed',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "e115742d-219d-4e11-a175-c97d1b1a5acb", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [60.0, 59.7, 59.5, 59.3, 59.1, 58.7, 58.4, 57.6, 57.1, 56.8, 56.5, 56.1, 55.8, 55.6, 55.5, 55.4]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('748066a2-594a-41e2-9955-ce9d248209ed');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Benin
# <div>
#
#
#             <div id="d08b4351-869f-471c-9ff6-d13be9767e2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d08b4351-869f-471c-9ff6-d13be9767e2b")) {
#                     Plotly.newPlot(
#                         'd08b4351-869f-471c-9ff6-d13be9767e2b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "a8d0e91d-b32f-4fad-adec-1974d186f5e2", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [69.8, 69.4, 69.1, 68.7, 68.3, 67.9, 67.4, 67.0, 66.5, 65.8, 65.0, 64.2, 63.3, 62.5, 61.7, 62.0]}],
# ...
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Uzbekistan
# <div>
#
#
#             <div id="53ec7a7f-55e5-476c-94ba-7a4e0806589b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("53ec7a7f-55e5-476c-94ba-7a4e0806589b")) {
#                     Plotly.newPlot(
#                         '53ec7a7f-55e5-476c-94ba-7a4e0806589b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "ae3b9ea2-7f12-4f2b-bee9-f81aeec052f9", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [72.0, 71.7, 71.6, 71.4, 71.2, 71.0, 78.0, 75.0, 73.0, 71.0, 69.9, 69.6, 69.4, 69.3, 69.1, 69.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('53ec7a7f-55e5-476c-94ba-7a4e0806589b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Vanuatu
# <div>
#
#
#             <div id="ac5e1ea3-a1d4-466e-82e2-e016cc941a4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ac5e1ea3-a1d4-466e-82e2-e016cc941a4b")) {
#                     Plotly.newPlot(
#                         'ac5e1ea3-a1d4-466e-82e2-e016cc941a4b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "20a8dd6c-edbc-4eaf-854a-f636a8196e54", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [74.1, 73.9, 73.8, 73.7, 73.8, 73.7, 73.6, 73.2, 73.4, 73.6, 73.6, 73.3, 72.4, 73.1, 72.5, 72.5]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ac5e1ea3-a1d4-466e-82e2-e016cc941a4b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Venezuela (Bolivarian Republic of)
# <div>
#
#
#             <div id="abb4d7ca-bd84-4d71-b1e7-1302928e1e98" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("abb4d7ca-bd84-4d71-b1e7-1302928e1e98")) {
#                     Plotly.newPlot(
#                         'abb4d7ca-bd84-4d71-b1e7-1302928e1e98',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "0dcc00bb-f79f-4cfe-9aee-fa68f1333dbd", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.0, 75.9, 75.7, 75.6, 75.4, 75.2, 75.0, 74.9, 74.7, 74.6, 74.4, 74.2, 74.0, 73.8, 73.6, 73.4]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('abb4d7ca-bd84-4d71-b1e7-1302928e1e98');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Viet Nam
# <div>
#
#
#             <div id="e4683f08-3290-46ed-8cb5-dd4a97154e58" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e4683f08-3290-46ed-8cb5-dd4a97154e58")) {
#                     Plotly.newPlot(
#                         'e4683f08-3290-46ed-8cb5-dd4a97154e58',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "a1dede88-c97d-4886-be12-ac5a3d5816cd", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [65.7, 65.4, 65.4, 64.7, 64.6, 64.4, 64.1, 63.8, 63.4, 63.0, 62.6, 62.2, 61.9, 61.5, 61.1, 68.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e4683f08-3290-46ed-8cb5-dd4a97154e58');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Yemen
# <div>
#
#
#             <div id="55b65fa1-46c1-4879-99ba-62505025a568" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("55b65fa1-46c1-4879-99ba-62505025a568")) {
#                     Plotly.newPlot(
#                         '55b65fa1-46c1-4879-99ba-62505025a568',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "99030190-ff1f-4600-841d-08f43860dbab", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [61.8, 61.1, 63.0, 59.2, 58.2, 58.0, 57.4, 55.7, 52.6, 58.0, 49.3, 47.9, 46.4, 45.5, 44.6, 43.8]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('55b65fa1-46c1-4879-99ba-62505025a568');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Zambia
# <div>
#
#
#             <div id="78132f1d-521e-4f83-8e13-0a8e632260a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("78132f1d-521e-4f83-8e13-0a8e632260a4")) {
#                     Plotly.newPlot(
#                         '78132f1d-521e-4f83-8e13-0a8e632260a4',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "77184936-5e77-41ab-8d4a-e1d13ff9b1c9", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [67.0, 59.2, 58.0, 56.6, 54.9, 52.4, 50.0, 48.2, 46.6, 45.4, 44.6, 44.3, 44.5, 44.8, 45.3, 46.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('78132f1d-521e-4f83-8e13-0a8e632260a4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Zimbabwe

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

countries = df['Country'].unique()
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111)

# X = 
for country in countries[:20]:
#     df_group.loc[country].iplot(y='Life expectancy ')
    df_group.loc[country].plot(y='Life expectancy ', ax=ax)

# %%
df['Life expectancy '].hist()

# %% [markdown]
# ### Displaying length of rows and columns in our dataset

# %%
df.shape
# Out:
# (2938, 22)

# %% [markdown]
# ### Use profiling to speed up EDA

# %%
# profile = pandas_profiling.ProfileReport(df)

# %%
# from IPython.core.display import display, HTML
# display(HTML(profile.html))

# %% [markdown]
# ### Display column names and background research on column descriptions

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# `Status`
# Developed or Developing status
#
# `Life expectancy`
# Life Expectancy in age
#
# `Adult Mortality`
# Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
#
# `infant deaths`
# Number of Infant Deaths per 1000 population
#
# `Alcohol`
# Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
#
# `percentage expenditure`
# Expenditure on health as a percentage of Gross Domestic Product per capita(%)
#
# `Hepatitis B`
# Hepatitis B (HepB) immunization coverage among 1-year-olds (%)
#
# `Measles`
# Measles - number of reported cases per 1000 population
#
# `BMI`
# Average Body Mass Index of entire population
#
# `under-five deaths`
# Number of under-five deaths per 1000 population
#
# `Polio`
# Polio (Pol3) immunization coverage among 1-year-olds (%)
#
# `Total expenditure`
# General government expenditure on health as a percentage of total government expenditure (%)
#
# `Diphtheria`
# Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
#
# `HIV/AIDS`
# Deaths per 1 000 live births HIV/AIDS (0-4 years)
#
# `GDP`
# Gross Domestic Product per capita (in USD)
#
# `Population`
# Population of the country
#
# `thinness 1-19 years`
# Prevalence of thinness among children and adolescents for Age 10 to 19 (% )
#
# `thinness 5-9 years`
# Prevalence of thinness among children for Age 5 to 9(%)
#
# `Income composition of resources`
# Human Development Index in terms of income composition of resources (index ranging from 0 to 1) url: http://hdr.undp.org/en/content/human-development-index-hdi
#
# `Schooling`
# Number of years of Schooling(years)

# %% [markdown]
# ### Mapping life expectency for 2015

# %%
print('Maximum year is', df['Year'].max())
print('Minimum year is', df['Year'].min())
# Out:
# Maximum year is 2015
# Minimum year is 2000

# %% [markdown]
# Let's filter by 2015 to make a map of life expectency per country.

# %%
df_2015 = df[df['Year']==2015]

# %% [markdown]
# ### Reading in the country codes tsv to make the map (file generated from UN stats webpage:
# https://unstats.un.org/unsd/methodology/m49/

# %%
country_codes = pd.read_csv('country_code_2.tsv',sep='\t')
country_codes.head()
# Out:
#   Country or Area  M49 code ISO-alpha3 code
# 0     Afghanistan         4             AFG
# 1   Aland Islands       248             ALA
# 2         Albania         8             ALB
# 3         Algeria        12             DZA
# 4  American Samoa        16             ASM

# %% [markdown]
# ### Matching countries to country names in country codes tsv data

# %%
df_2015.replace("Côte d'Ivoire", "Cote d'Ivoire", inplace=True)
df_2015.replace('Swaziland', 'Eswatini', inplace=True)
df_2015.replace('The former Yugoslav republic of Macedonia', 'North Macedonia', inplace=True)

df_2015_map = df_2015.merge(country_codes, how="left", left_on="Country",right_on="Country or Area")
df_2015_map.rename(columns={'M49 code': 'id'}, inplace=True)
df_2015_map.drop(columns=['ISO-alpha3 code', 'Country or Area'], inplace=True)

df_2015_map['tooltip']=df_2015_map['Country']+': '+df_2015_map['Life expectancy '].astype(str) + ' yr'

# %% [markdown]
# ### Looking at the codes from geojson file (map feature) which defines border for all the countries.

# %%
# map_codes = [x['id'] for x in data.world_110m()['objects']['countries']['geometries']]
# map_codes

# %% [markdown]
# ### Making the map!

# %%
source = alt.topo_feature(data.world_110m.url,'countries')

plt = alt.Chart(source).mark_geoshape().encode(
    color=alt.Color('Life expectancy :Q', legend=alt.Legend(title='Years')),
    tooltip='tooltip:N'
).transform_lookup(
   lookup='id',
   from_=alt.LookupData(df_2015_map, 'id', ['Life expectancy ', 'tooltip'])
).project(
   type='equirectangular'
).properties(
    width=900,
    height=540,
    title=('Life Expectency in Years')
)

# %%
plt

# %% [markdown]
# ## Formulating the research question

# %% [markdown]
# **What are the most important feaures which contribute to life expectancy?**
#
# **How can we best predict life expectancy?**

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# ### Drop NaN's and check remaining length of dataframe

# %%
df_nona = df.dropna()

# %%
df_nona.shape
# Out:
# (1649, 22)

# %% [markdown]
# ### Rename Life expectancy column to target

# %%
df_nona.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df_nona.rename(columns={'Life expectancy ':'target'}, inplace=True)

# %%
df_nona.head()
# Out:
#        Country  Year      Status  target  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing    65.0            263.0             62
# 1  Afghanistan  2014  Developing    59.9            271.0             64
# 2  Afghanistan  2013  Developing    59.9            268.0             66
# 3  Afghanistan  2012  Developing    59.5            272.0             69
# 4  Afghanistan  2011  Developing    59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Make bootstrap with replacement to normalize the target column and find the true mean as a place to split the data at a certain age, and anything a above that age will be 1 for long life expectancy and 0 for low life expectancy.

# %%
age = []
for i in range(1000):
    x_age = np.random.choice(df_nona['target'],size=500)
    age.append(x_age.mean())
print(np.mean(age))
# Out:
# 69.3061334

# %%
df_nona['target'].describe()
# Out:
# count    1649.000000
# mean       69.302304
# std         8.796834
# min        44.000000
# 25%        64.400000
# 50%        71.700000
# 75%        75.000000
# max        89.000000
# Name: target, dtype: float64

# %%
median_age = np.median(df_nona['target'])
df_nona['target'] = df_nona.target.apply(lambda x: 1 if x >= median_age  else 0)

# %%
df_nona.head()
# Out:
#        Country  Year      Status  target  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing       0            263.0             62
# 1  Afghanistan  2014  Developing       0            271.0             64
# 2  Afghanistan  2013  Developing       0            268.0             66
# 3  Afghanistan  2012  Developing       0            272.0             69
# 4  Afghanistan  2011  Developing       0            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df_nona['Country'].nunique()
# Out:
# 133

# %%
count = 0 
for country in df_nona['Country'].unique() : 
    check = df_nona.loc[df_nona['Country']== country, 'target'].nunique()
    if (check == 1):
      
        count +=1
    else:
        print(country)
# Out:
# Azerbaijan
# Bangladesh
# Belarus
# Brazil
# Bulgaria
# Cabo Verde
# Colombia
# Dominican Republic
# El Salvador
# Guatemala
# Honduras
# Iraq
# Latvia
# Lithuania
# Maldives
# Mauritius
# Morocco
# Nicaragua
# Romania
# Russian Federation
# Samoa
# Sri Lanka
# Suriname
# Thailand
# Tonga
# Trinidad and Tobago
# Turkey
# Ukraine
# Vanuatu

# %%
count / df_nona['Country'].nunique()
# Out:
# 0.7819548872180451

# %%
#show that the model is able to generalize to different countries the model has not seen before

# %%
df_nona[df_nona['Country']=='Brazil']
# Out:
#     Country  Year      Status  target  Adult Mortality  infant deaths  \
# 353  Brazil  2014  Developing       1            144.0             44
# 354  Brazil  2013  Developing       1            146.0             46
# 355  Brazil  2012  Developing       1            148.0             49
# 356  Brazil  2011  Developing       1            152.0             51
# 357  Brazil  2010  Developing       1            154.0             54
# 358  Brazil  2009  Developing       1            157.0             57
# 359  Brazil  2008  Developing       1            158.0             61
# 360  Brazil  2007  Developing       1            159.0             65
# 361  Brazil  2006  Developing       1            161.0             70
# 362  Brazil  2005  Developing       1            163.0             75
# 363  Brazil  2004  Developing       1             17.0             81
# 364  Brazil  2003  Developing       1            172.0             88
# 365  Brazil  2002  Developing       0            176.0             95
# 366  Brazil  2001  Developing       0            179.0            103
# 367  Brazil  2000  Developing       1            183.0            111
#
#      Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 353     7.32               83.164654         96.0       876  ...   96.0
# 354     7.24              916.270845         96.0       220  ...   96.0
# 355     7.55              843.194626         96.0         2  ...   96.0
# 356     7.58             1084.999766         98.0        43  ...   98.0
# 357     7.52             1111.191325         96.0        68  ...   99.0
# 358     7.33              564.523390         99.0         0  ...   99.0
# 359     7.21              526.378064         96.0         0  ...   99.0
# 360     7.19              394.932130         99.0         0  ...   99.0
# 361     7.10               30.303747         99.0        57  ...   99.0
# 362     6.97               23.763701         98.0         6  ...   99.0
# 363     6.85              186.609049         96.0         0  ...   99.0
# 364     6.95               15.857812         97.0         2  ...   99.0
# 365     7.00              140.982477         92.0         1  ...   99.0
# 366     7.13              149.480209         91.0         1  ...   99.0
# 367     7.26              179.477729         94.0        36  ...   99.0
#
#      Total expenditure  Diphtheria    HIV/AIDS           GDP   Population  \
# 353               8.32         93.0        0.1   1226.617310   24213133.0
# 354               8.48         97.0        0.1  12216.944600    2248632.0
# 355               8.26         95.0        0.1  12291.466850     256983.0
# 356               8.90         99.0        0.1  13167.472890  198686688.0
# 357               8.27         99.0        0.1  11224.154800  196796269.0
# 358               8.65         99.0        0.1   8553.384700  194895996.0
# 359               8.24         99.0        0.1   8787.613750   19297929.0
# 360               8.28         99.0        0.1   7313.557962   19126637.0
# 361               8.36         99.0        0.1    586.145975   18912412.0
# 362               8.27         99.0        0.1    477.182746  186917361.0
# 363               7.70         99.0        0.1   3623.476670  184738458.0
# 364               6.94         99.0        0.1    359.587582  182482149.0
# 365               7.13         99.0        0.1   2819.649531    1815121.0
# 366               7.19         98.0        0.1   3146.951770    1777567.0
# 367               7.30         98.0        0.1   3739.119360  175287587.0
#
#       thinness  1-19 years   thinness 5-9 years  \
# 353                    2.7                  2.7
# 354                    2.8                  2.7
# 355                    2.8                  2.8
# 356                    2.9                  2.8
# 357                    2.9                  2.9
# 358                    3.0                  2.9
# 359                    3.0                  3.0
# 360                    3.1                  3.0
# 361                    3.1                  3.1
# 362                    3.2                  3.1
# 363                    3.2                  3.2
# 364                    3.3                  3.3
# 365                    3.3                  3.3
# 366                    3.4                  3.4
# 367                    3.4                  3.4
#
#      Income composition of resources  Schooling
# 353                            0.747       15.2
# 354                            0.734       14.2
# 355                            0.730       14.2
# 356                            0.724       14.0
# 357                            0.716       13.8
# 358                            0.714       13.8
# 359                            0.704       13.3
# 360                            0.700       13.5
# 361                            0.698       13.8
# 362                            0.694       13.8
# 363                            0.695       14.0
# 364                            0.699       14.8
# 365                            0.692       14.6
# 366                            0.685       14.3
# 367                            0.677       14.1
#
# [15 rows x 22 columns]

# %%
df_nona.target.value_counts()
# Out:
# 1    828
# 0    821
# Name: target, dtype: int64

# %%
#developed = 0, developing =1
#look into dropping one
df_nona = pd.concat([df_nona, pd.get_dummies(df_nona['Status'])], axis=1)
df_nona.head()
# Out:
#        Country  Year      Status  target  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing       0            263.0             62
# 1  Afghanistan  2014  Developing       0            271.0             64
# 2  Afghanistan  2013  Developing       0            268.0             66
# 3  Afghanistan  2012  Developing       0            272.0             69
# 4  Afghanistan  2011  Developing       0            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Diphtheria   \
# 0     0.01               71.279624         65.0      1154  ...         65.0
# 1     0.01               73.523582         62.0       492  ...         62.0
# 2     0.01               73.219243         64.0       430  ...         64.0
# 3     0.01               78.184215         67.0      2787  ...         67.0
# 4     0.01                7.097109         68.0      3013  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling  Developed  \
# 0                 17.3                            0.479       10.1          0
# 1                 17.5                            0.476       10.0          0
# 2                 17.7                            0.470        9.9          0
# 3                 18.0                            0.463        9.8          0
# 4                 18.2                            0.454        9.5          0
#
#    Developing
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 24 columns]

# %%
df_nona.drop(['Status'], axis=1, inplace=True)
df_nona.head()
# Out:
#        Country  Year  target  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015       0            263.0             62     0.01
# 1  Afghanistan  2014       0            271.0             64     0.01
# 2  Afghanistan  2013       0            268.0             66     0.01
# 3  Afghanistan  2012       0            272.0             69     0.01
# 4  Afghanistan  2011       0            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Diphtheria   \
# 0               71.279624         65.0      1154   19.1  ...         65.0
# 1               73.523582         62.0       492   18.6  ...         62.0
# 2               73.219243         64.0       430   18.1  ...         64.0
# 3               78.184215         67.0      2787   17.6  ...         67.0
# 4                7.097109         68.0      3013   17.2  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling  Developed  \
# 0                 17.3                            0.479       10.1          0
# 1                 17.5                            0.476       10.0          0
# 2                 17.7                            0.470        9.9          0
# 3                 18.0                            0.463        9.8          0
# 4                 18.2                            0.454        9.5          0
#
#    Developing
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Define X and y

# %%
from random import randint
all_countries = df.Country.unique()
# Choose random countries
num_to_withhold = 100
withhold_countries = set([])
while len(withhold_countries) < num_to_withhold:
    # Get a random integer so we can choose a random country
    withhold_countries.add(all_countries[randint(0, len(all_countries) - 1)])

withhold_countries = list(withhold_countries)
training_countries = [country for country in all_countries if (country not in withhold_countries)]


df_train = df_nona[df_nona['Country'].isin(training_countries)]
df_test = df_nona[df_nona['Country'].isin(withhold_countries)]

# %%
100/len(all_countries)
# Out:
# 0.5181347150259067

# %%
y = df_train['target']
X = df_train.drop(['target'], axis=1)

# %%
X.drop(['Country'], axis=1, inplace = True)

# %% [markdown]
# ### Split data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree 
classifier = DecisionTreeClassifier(random_state=10)  
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=10,
#             splitter='best')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc

acc = accuracy_score(y_test,y_pred) * 100
print("Accuracy is :{0}".format(acc))

# Check the AUC for predictions
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
print("\nAUC is :{0}".format(round(roc_auc,2)))

# Create and print a confusion matrix 
print('\nConfusion Matrix')
print('----------------')
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Accuracy is :91.2621359223301
#
# AUC is :0.91
#
# Confusion Matrix
# ----------------
# Predicted    0   1  All
# True
# 0          103   8  111
# 1           10  85   95
# All        113  93  206

# %%
# The model misclassified 33 rows

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

classifier.feature_importances_
def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(8,8))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")

plot_feature_importances(classifier)

# %% [markdown]
# The Income composition of resources which is the Human Development Index combines education, life expectency, and GNI index (economic factor).

# %% [markdown]
# ### Let's try Random Forrest but this time dropping Income composition of resources and Adult Mortality

# %%
y
X.drop(['Adult Mortality','Income composition of resources','Population','GDP','Year'], axis=1, inplace=True)

# %%
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
forest = RandomForestClassifier(n_estimators=100, max_depth= 5)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
forest.score(X_train, y_train)
# Out:
# 0.9577235772357724

# %%
forest.score(X_test, y_test)
# Out:
# 0.9271844660194175

# %%
plot_feature_importances(forest)

# %% [markdown]
# ### Grid search to optimize the random forest model

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [30, 100, 300],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [2, 4, 6]
}

# %%
gs = GridSearchCV(forest, param_grid, cv=5)
gs.fit(X_train, y_train)
gs.score(X_test, y_test)
gs.best_params_
# Out:
# {'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}

# %%
gs.score(X_test, y_test)
# Out:
# 0.912621359223301

# %%
gs.best_score_
# Out:
# 0.9040650406504065

# %%
forest2 = RandomForestClassifier(min_samples_split=2, min_samples_leaf=2, n_estimators=30, max_depth= 5)
forest2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
forest2.score(X_train, y_train)
# Out:
# 0.943089430894309

# %%
forest2.score(X_test, y_test)
# Out:
# 0.9077669902912622

# %%
plot_feature_importances(forest2)

# %% [markdown]
# ### Conclusions

# %% [markdown]
# School is an important factor in predicting whether people live long (> 71 years old) or not. Followed by AIDS and BMI. If this was a business such as a non-governmental organization trying to improve people's lives, then perhaps improving the healthcare system to lower mortality and make education available to all.

# %%
df_test.head()
# Out:
#        Country  Year  target  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015       0            263.0             62     0.01
# 1  Afghanistan  2014       0            271.0             64     0.01
# 2  Afghanistan  2013       0            268.0             66     0.01
# 3  Afghanistan  2012       0            272.0             69     0.01
# 4  Afghanistan  2011       0            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Diphtheria   \
# 0               71.279624         65.0      1154   19.1  ...         65.0
# 1               73.523582         62.0       492   18.6  ...         62.0
# 2               73.219243         64.0       430   18.1  ...         64.0
# 3               78.184215         67.0      2787   17.6  ...         67.0
# 4                7.097109         68.0      3013   17.2  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling  Developed  \
# 0                 17.3                            0.479       10.1          0
# 1                 17.5                            0.476       10.0          0
# 2                 17.7                            0.470        9.9          0
# 3                 18.0                            0.463        9.8          0
# 4                 18.2                            0.454        9.5          0
#
#    Developing
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 23 columns]

# %%
y_test_2 = df_test['target']

X_test_2 = df_test.drop(['Country', 'target','Adult Mortality','Income composition of resources','Population','GDP','Year'], axis=1)
y_pred_2 = forest2.predict(X_test_2)

acc = accuracy_score(y_test_2,y_pred_2) * 100
print("Accuracy is :{0}".format(acc))

# Check the AUC for predictions
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_2, y_pred_2)
roc_auc = auc(false_positive_rate, true_positive_rate)
print("\nAUC is :{0}".format(round(roc_auc,2)))

# Create and print a confusion matrix 
print('\nConfusion Matrix')
print('----------------')
pd.crosstab(y_test_2, y_pred_2, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Accuracy is :85.74879227053141
#
# AUC is :0.85
#
# Confusion Matrix
# ----------------
# Predicted    0    1  All
# True
# 0          305   95  400
# 1           23  405  428
# All        328  500  828

# %% [markdown]
# It's 88% accurate on countries it is never seen before when 70 countries (36%) were completely withheld from training.
#
# When we increased the number to 100 countries (trained on the remaining), the accuracy dropped to 85%

# %%
num_to_withhold
# Out:
# 100
