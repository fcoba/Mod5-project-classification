# %% [markdown]
# # Mod 5 Project: Classifying Life Expectancy (World Health Organization Data)

# %% [markdown]
# **Group Partners: Filis, Manisha, Pablo**
#
# ___

# %% [markdown]
# Ran the following commands in terminal to install Profiling (visualizing data), and Altair (map):
#
# ```
# conda install -c conda-forge altair vega_datasets notebook vega
# ```
#
# ```
# conda install -c anaconda pandas-profiling
# ```

# %%
# !pip install altair vega_datasets notebook vega
# Out:
# Requirement already satisfied: altair in /anaconda3/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: vega_datasets in /anaconda3/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: notebook in /anaconda3/lib/python3.7/site-packages (5.7.4)
# Requirement already satisfied: vega in /anaconda3/lib/python3.7/site-packages (2.3.2)
# Requirement already satisfied: jinja2 in /anaconda3/lib/python3.7/site-packages (from altair) (2.10)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (from altair) (1.15.4)
# Requirement already satisfied: jsonschema in /anaconda3/lib/python3.7/site-packages (from altair) (2.6.0)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from altair) (1.12.0)
# Requirement already satisfied: toolz in /anaconda3/lib/python3.7/site-packages (from altair) (0.9.0)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.7/site-packages (from altair) (0.23.4)
# Requirement already satisfied: entrypoints in /anaconda3/lib/python3.7/site-packages (from altair) (0.2.3)
# Requirement already satisfied: pyzmq>=17 in /anaconda3/lib/python3.7/site-packages (from notebook) (17.1.2)
# Requirement already satisfied: traitlets>=4.2.1 in /anaconda3/lib/python3.7/site-packages (from notebook) (4.3.2)
# Requirement already satisfied: ipython-genutils in /anaconda3/lib/python3.7/site-packages (from notebook) (0.2.0)
# Requirement already satisfied: tornado>=4 in /anaconda3/lib/python3.7/site-packages (from notebook) (5.1.1)
# Requirement already satisfied: Send2Trash in /anaconda3/lib/python3.7/site-packages (from notebook) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /anaconda3/lib/python3.7/site-packages (from notebook) (0.8.1)
# Requirement already satisfied: nbformat in /anaconda3/lib/python3.7/site-packages (from notebook) (4.4.0)
# Requirement already satisfied: nbconvert in /anaconda3/lib/python3.7/site-packages (from notebook) (5.4.0)
# Requirement already satisfied: prometheus-client in /anaconda3/lib/python3.7/site-packages (from notebook) (0.5.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /anaconda3/lib/python3.7/site-packages (from notebook) (5.2.4)
# Requirement already satisfied: ipykernel in /anaconda3/lib/python3.7/site-packages (from notebook) (5.1.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /anaconda3/lib/python3.7/site-packages (from notebook) (4.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2->altair) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas->altair) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas->altair) (2018.7)
# Requirement already satisfied: decorator in /anaconda3/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook) (4.3.0)
# Requirement already satisfied: mistune>=0.8.1 in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook) (0.8.4)
# Requirement already satisfied: pygments in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook) (2.3.1)
# Requirement already satisfied: bleach in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook) (1.4.2)
# Requirement already satisfied: testpath in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook) (0.4.2)
# Requirement already satisfied: defusedxml in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook) (0.5.0)
# Requirement already satisfied: ipython>=5.0.0 in /anaconda3/lib/python3.7/site-packages (from ipykernel->notebook) (7.2.0)
# Requirement already satisfied: webencodings in /anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook) (0.5.1)
# Requirement already satisfied: backcall in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (2.0.7)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.13.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (4.6.0)
# Requirement already satisfied: setuptools>=18.5 in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (40.6.3)
# Requirement already satisfied: pickleshare in /anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.7.5)
# Requirement already satisfied: wcwidth in /anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook) (0.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook) (0.6.0)

# %% [markdown]
# ### Import libraries

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Requirement already satisfied: plotly in /anaconda3/lib/python3.7/site-packages (3.10.0)
# Requirement already satisfied: decorator>=4.0.6 in /anaconda3/lib/python3.7/site-packages (from plotly) (4.3.0)
# Requirement already satisfied: nbformat>=4.2 in /anaconda3/lib/python3.7/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from plotly) (2.21.0)
# Requirement already satisfied: pytz in /anaconda3/lib/python3.7/site-packages (from plotly) (2018.7)
# Requirement already satisfied: retrying>=1.3.3 in /anaconda3/lib/python3.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)
# Requirement already satisfied: jupyter-core in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied: ipython-genutils in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->plotly) (2018.11.29)
# Requirement already satisfied: cufflinks in /anaconda3/lib/python3.7/site-packages (0.16)
# Requirement already satisfied: setuptools>=34.4.1 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (40.6.3)
# Requirement already satisfied: plotly<4.0.0a0,>=3.0.0 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (3.10.0)
# Requirement already satisfied: pandas>=0.19.2 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (0.23.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (7.4.2)
# Requirement already satisfied: colorlover>=0.2.1 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: ipython>=5.3.0 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (7.2.0)
# Requirement already satisfied: six>=1.9.0 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (1.12.0)
# Requirement already satisfied: numpy>=1.9.2 in /anaconda3/lib/python3.7/site-packages (from cufflinks) (1.15.4)
# Requirement already satisfied: decorator>=4.0.6 in /anaconda3/lib/python3.7/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (4.3.0)
# Requirement already satisfied: retrying>=1.3.3 in /anaconda3/lib/python3.7/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (1.3.3)
# Requirement already satisfied: nbformat>=4.2 in /anaconda3/lib/python3.7/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (2.21.0)
# Requirement already satisfied: pytz in /anaconda3/lib/python3.7/site-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (2018.7)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas>=0.19.2->cufflinks) (2.7.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.3.2)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (2.0.7)
# Requirement already satisfied: pickleshare in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: backcall in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (0.13.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (4.6.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (0.1.0)
# Requirement already satisfied: pygments in /anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks) (2.3.1)
# Requirement already satisfied: ipython-genutils in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly<4.0.0a0,>=3.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly<4.0.0a0,>=3.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: jupyter-core in /anaconda3/lib/python3.7/site-packages (from nbformat>=4.2->plotly<4.0.0a0,>=3.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (1.24.1)
# Requirement already satisfied: tornado>=4.2 in /anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.1.1)
# Requirement already satisfied: jupyter-client in /anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.2.4)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (5.7.4)
# Requirement already satisfied: wcwidth in /anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.3.0->cufflinks) (0.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks) (0.6.0)
# Requirement already satisfied: pyzmq>=13 in /anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (17.1.2)
# Requirement already satisfied: nbconvert in /anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (5.4.0)
# Requirement already satisfied: prometheus-client in /anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.5.0)
# Requirement already satisfied: Send2Trash in /anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: jinja2 in /anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (2.10)
# Requirement already satisfied: terminado>=0.8.1 in /anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.8.1)
# Requirement already satisfied: mistune>=0.8.1 in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: bleach in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: testpath in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.4.2)
# Requirement already satisfied: defusedxml in /anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.1.0)
# Requirement already satisfied: webencodings in /anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)

# %%
import pandas as pd  
import numpy as np

import plotly.plotly as py 
import plotly 
import cufflinks as cf 
import pandas as pd 
import numpy as np 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True) 
cf.go_offline()


#Making Visualizations
import altair as alt
alt.renderers.enable('notebook')
from vega_datasets import data

#Displaying EDA Profile
import pandas_profiling

#Disabling warnings 
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Read in csv and display first few rows

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#      ...      Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0    ...        6.0               8.16         65.0        0.1  584.259210
# 1    ...       58.0               8.18         62.0        0.1  612.696514
# 2    ...       62.0               8.13         64.0        0.1  631.744976
# 3    ...       67.0               8.52         67.0        0.1  669.959000
# 4    ...       68.0               7.87         68.0        0.1   63.537231
#
#    Population   thinness  1-19 years   thinness 5-9 years  \
# 0  33736494.0                   17.2                 17.3
# 1    327582.0                   17.5                 17.5
# 2  31731688.0                   17.7                 17.7
# 3   3696958.0                   17.9                 18.0
# 4   2978599.0                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Seeing if data is time series

# %%
df_group = df.set_index(['Country','Year'])
df_group.head()
# Out:
#                       Status  Life expectancy   Adult Mortality  \
# Country     Year
# Afghanistan 2015  Developing              65.0            263.0
#             2014  Developing              59.9            271.0
#             2013  Developing              59.9            268.0
#             2012  Developing              59.5            272.0
#             2011  Developing              59.2            275.0
#
#                   infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country     Year
# Afghanistan 2015             62     0.01               71.279624         65.0
#             2014             64     0.01               73.523582         62.0
#             2013             66     0.01               73.219243         64.0
#             2012             69     0.01               78.184215         67.0
#             2011             71     0.01                7.097109         68.0
#
#                   Measles    BMI   under-five deaths   Polio  \
# Country     Year
# Afghanistan 2015      1154   19.1                  83    6.0
#             2014       492   18.6                  86   58.0
#             2013       430   18.1                  89   62.0
#             2012      2787   17.6                  93   67.0
#             2011      3013   17.2                  97   68.0
#
#                   Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# Country     Year
# Afghanistan 2015               8.16         65.0        0.1  584.259210
#             2014               8.18         62.0        0.1  612.696514
#             2013               8.13         64.0        0.1  631.744976
#             2012               8.52         67.0        0.1  669.959000
#             2011               7.87         68.0        0.1   63.537231
#
#                   Population   thinness  1-19 years   thinness 5-9 years  \
# Country     Year
# Afghanistan 2015  33736494.0                   17.2                 17.3
#             2014    327582.0                   17.5                 17.5
#             2013  31731688.0                   17.7                 17.7
#             2012   3696958.0                   17.9                 18.0
#             2011   2978599.0                   18.2                 18.2
#
#                   Income composition of resources  Schooling
# Country     Year
# Afghanistan 2015                            0.479       10.1
#             2014                            0.476       10.0
#             2013                            0.470        9.9
#             2012                            0.463        9.8
#             2011                            0.454        9.5

# %%
countries = df['Country'].unique()
for country in countries:
    df_group.loc[country].iplot(y='Life expectancy ')
    print(country)
# Out:
# <div>
#
#
#             <div id="0c8a92fd-17e1-4bdd-b04c-6115cc37d85d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0c8a92fd-17e1-4bdd-b04c-6115cc37d85d")) {
#                     Plotly.newPlot(
#                         '0c8a92fd-17e1-4bdd-b04c-6115cc37d85d',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "4658c73f-e31f-4ce3-a903-0f5d842b810c", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [65.0, 59.9, 59.9, 59.5, 59.2, 58.8, 58.6, 58.1, 57.5, 57.3, 57.3, 57.0, 56.7, 56.2, 55.3, 54.8]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0c8a92fd-17e1-4bdd-b04c-6115cc37d85d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Afghanistan
# <div>
#
#
#             <div id="7f676453-520e-440a-a066-4c54feae4c09" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7f676453-520e-440a-a066-4c54feae4c09")) {
#                     Plotly.newPlot(
#                         '7f676453-520e-440a-a066-4c54feae4c09',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "37e6e242-b6e4-4c7e-86c2-2dd120a12845", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [77.8, 77.5, 77.2, 76.9, 76.6, 76.2, 76.1, 75.3, 75.9, 74.2, 73.5, 73.0, 72.8, 73.3, 73.6, 72.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7f676453-520e-440a-a066-4c54feae4c09');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Albania
# <div>
#
#
#             <div id="d48f054e-f532-4af9-bd88-2242d156a81e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d48f054e-f532-4af9-bd88-2242d156a81e")) {
#                     Plotly.newPlot(
#                         'd48f054e-f532-4af9-bd88-2242d156a81e',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "f5f456f3-c314-4701-9946-f90c10e740d9", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [75.6, 75.4, 75.3, 75.1, 74.9, 74.7, 74.4, 74.1, 73.8, 73.4, 72.9, 72.3, 71.7, 71.6, 71.4, 71.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d48f054e-f532-4af9-bd88-2242d156a81e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Algeria
# <div>
#
#
#             <div id="d433483e-2806-4353-a9a4-139157e3d2c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d433483e-2806-4353-a9a4-139157e3d2c3")) {
#                     Plotly.newPlot(
#                         'd433483e-2806-4353-a9a4-139157e3d2c3',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "fc90e030-27c3-4be9-a472-5d88ec455fa7", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [52.4, 51.7, 51.1, 56.0, 51.0, 49.6, 49.1, 48.7, 48.2, 47.7, 47.4, 47.1, 46.8, 46.5, 45.7, 45.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d433483e-2806-4353-a9a4-139157e3d2c3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Angola
# <div>
#
#
#             <div id="d06e3032-52ab-43f2-a318-1e4caa91f534" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d06e3032-52ab-43f2-a318-1e4caa91f534")) {
#                     Plotly.newPlot(
#                         'd06e3032-52ab-43f2-a318-1e4caa91f534',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "505c8ce6-30d2-4654-9720-e79457865bfc", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.4, 76.2, 76.1, 75.9, 75.7, 75.6, 75.4, 75.2, 75.0, 74.8, 74.6, 74.4, 74.2, 74.0, 73.8, 73.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d06e3032-52ab-43f2-a318-1e4caa91f534');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Antigua and Barbuda
# <div>
#
#
#             <div id="6e5817d9-37b3-4fb2-aef3-0d956f33ea1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6e5817d9-37b3-4fb2-aef3-0d956f33ea1c")) {
#                     Plotly.newPlot(
#                         '6e5817d9-37b3-4fb2-aef3-0d956f33ea1c',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "d10a7572-27b1-46ba-9ea1-73caf32084c8", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.3, 76.2, 76.0, 75.9, 75.7, 75.5, 75.6, 75.4, 74.8, 75.2, 74.9, 74.7, 74.1, 74.1, 74.0, 74.1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6e5817d9-37b3-4fb2-aef3-0d956f33ea1c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Argentina
# <div>
#
#
#             <div id="54e3d556-d6a6-4b3f-a058-b484db6ded8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("54e3d556-d6a6-4b3f-a058-b484db6ded8c")) {
#                     Plotly.newPlot(
#                         '54e3d556-d6a6-4b3f-a058-b484db6ded8c',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "6ee617e5-a71a-41b6-861e-66168d829c7c", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [74.8, 74.6, 74.4, 74.4, 73.9, 73.5, 73.3, 73.2, 73.5, 72.9, 73.0, 73.0, 72.7, 72.6, 72.6, 72.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('54e3d556-d6a6-4b3f-a058-b484db6ded8c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Armenia
# <div>
#
#
#             <div id="501f89a4-cc37-475f-b9f8-0d3d38ad4aa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("501f89a4-cc37-475f-b9f8-0d3d38ad4aa7")) {
#                     Plotly.newPlot(
#                         '501f89a4-cc37-475f-b9f8-0d3d38ad4aa7',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "11c74fe2-35c2-4c8f-99a7-3762492be2b5", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [82.8, 82.7, 82.5, 82.3, 82.0, 81.9, 81.7, 81.3, 81.3, 81.2, 81.0, 86.0, 83.0, 79.9, 79.9, 79.5]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('501f89a4-cc37-475f-b9f8-0d3d38ad4aa7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Australia
# <div>
#
#
#             <div id="ba9c00c8-f899-4fea-8d56-a4e2ea81d7ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ba9c00c8-f899-4fea-8d56-a4e2ea81d7ca")) {
#                     Plotly.newPlot(
#                         'ba9c00c8-f899-4fea-8d56-a4e2ea81d7ca',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "475c1485-5718-4e79-8248-750f08ceaa11", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [81.5, 81.4, 81.1, 88.0, 88.0, 84.0, 82.0, 84.0, 81.0, 79.8, 79.4, 79.3, 78.8, 78.7, 78.6, 78.1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ba9c00c8-f899-4fea-8d56-a4e2ea81d7ca');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Austria
# <div>
#
#
#             <div id="eb83c85b-6a92-4d5a-a93c-1dd9cdc373a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eb83c85b-6a92-4d5a-a93c-1dd9cdc373a3")) {
#                     Plotly.newPlot(
#                         'eb83c85b-6a92-4d5a-a93c-1dd9cdc373a3',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "c7bc8482-f161-44a3-bfcb-260aecb7fb77", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [72.7, 72.5, 72.2, 71.9, 71.6, 71.1, 78.0, 73.0, 73.0, 69.2, 68.4, 68.4, 67.8, 67.8, 67.5, 66.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('eb83c85b-6a92-4d5a-a93c-1dd9cdc373a3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Azerbaijan
# <div>
#
#
#             <div id="c5c0f3ec-e983-4ce1-bcaf-34b029dabb37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c5c0f3ec-e983-4ce1-bcaf-34b029dabb37")) {
#                     Plotly.newPlot(
#                         'c5c0f3ec-e983-4ce1-bcaf-34b029dabb37',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "d02a1571-34ac-46bc-bf73-7504977f2ab9", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.1, 75.4, 74.8, 74.9, 75.0, 75.0, 74.6, 74.5, 74.4, 74.2, 74.1, 73.8, 73.2, 73.1, 72.9, 72.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c5c0f3ec-e983-4ce1-bcaf-34b029dabb37');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Bahamas
# <div>
#
#
#             <div id="17cd62bd-b90f-448f-b672-81b4e1ed7e58" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("17cd62bd-b90f-448f-b672-81b4e1ed7e58")) {
#                     Plotly.newPlot(
#                         '17cd62bd-b90f-448f-b672-81b4e1ed7e58',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "6cba86a2-d056-431c-b4a6-8e814c9fabe0", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.9, 76.8, 76.7, 76.5, 76.1, 76.1, 76.0, 75.8, 75.6, 75.5, 75.3, 75.2, 75.0, 74.9, 74.7, 74.5]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('17cd62bd-b90f-448f-b672-81b4e1ed7e58');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Bahrain
# <div>
#
#
#             <div id="a56e2ff0-f6d5-427b-8b07-eb60d4f7afb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a56e2ff0-f6d5-427b-8b07-eb60d4f7afb2")) {
#                     Plotly.newPlot(
#                         'a56e2ff0-f6d5-427b-8b07-eb60d4f7afb2',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "4199fa6c-9e73-456f-9bf0-119cdf662477", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [71.8, 71.4, 71.0, 77.0, 73.0, 69.9, 69.5, 69.1, 68.6, 68.2, 67.8, 67.3, 66.8, 66.3, 65.8, 65.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a56e2ff0-f6d5-427b-8b07-eb60d4f7afb2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Bangladesh
# <div>
#
#
#             <div id="52ada38a-92b1-4d52-8226-9920a3104632" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("52ada38a-92b1-4d52-8226-9920a3104632")) {
#                     Plotly.newPlot(
#                         '52ada38a-92b1-4d52-8226-9920a3104632',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "86ffc4a5-85b3-4d1e-aaa1-1413e57f0ab1", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [75.5, 75.4, 75.2, 75.1, 74.9, 74.7, 74.6, 74.4, 74.2, 74.1, 73.9, 73.8, 73.7, 73.5, 73.4, 73.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('52ada38a-92b1-4d52-8226-9920a3104632');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Barbados
# <div>
#
#
#             <div id="21957796-9559-4de3-9568-fbf6d64b42c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("21957796-9559-4de3-9568-fbf6d64b42c1")) {
#                     Plotly.newPlot(
#                         '21957796-9559-4de3-9568-fbf6d64b42c1',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "3a058e91-1561-450f-a0fa-70c7b6725f4a", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [72.3, 72.0, 71.7, 71.9, 72.0, 73.0, 70.0, 70.0, 69.8, 68.9, 68.1, 68.2, 67.7, 67.2, 67.7, 68.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('21957796-9559-4de3-9568-fbf6d64b42c1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Belarus
# <div>
#
#
#             <div id="072ba0d3-f7a3-4fa7-b6f7-ded774bebf3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("072ba0d3-f7a3-4fa7-b6f7-ded774bebf3a")) {
#                     Plotly.newPlot(
#                         '072ba0d3-f7a3-4fa7-b6f7-ded774bebf3a',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "173ba979-d3d3-4c5c-9e0f-742b0a2f2d6e", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [81.1, 89.0, 87.0, 83.0, 83.0, 80.0, 79.8, 79.5, 79.5, 79.4, 78.9, 78.8, 78.3, 78.0, 78.0, 77.6]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('072ba0d3-f7a3-4fa7-b6f7-ded774bebf3a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Belgium
# <div>
#
#
#             <div id="fe7b7435-96ad-4fc0-a688-05e97e1bda56" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fe7b7435-96ad-4fc0-a688-05e97e1bda56")) {
#                     Plotly.newPlot(
#                         'fe7b7435-96ad-4fc0-a688-05e97e1bda56',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "be55d6a0-33c2-4dbd-ba21-e6436a57f19d", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [71.0, 70.0, 69.8, 69.4, 69.4, 69.5, 69.5, 69.6, 69.6, 69.4, 69.0, 68.7, 68.4, 68.5, 68.2, 68.3]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('fe7b7435-96ad-4fc0-a688-05e97e1bda56');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Belize
# <div>
#
#
#             <div id="6237d174-19b5-4f87-a182-25a4d95422db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6237d174-19b5-4f87-a182-25a4d95422db")) {
#                     Plotly.newPlot(
#                         '6237d174-19b5-4f87-a182-25a4d95422db',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "27f4ca8d-4f4b-4660-8f46-d86869db8494", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [60.0, 59.7, 59.5, 59.3, 59.1, 58.7, 58.4, 57.6, 57.1, 56.8, 56.5, 56.1, 55.8, 55.6, 55.5, 55.4]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6237d174-19b5-4f87-a182-25a4d95422db');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Benin
# <div>
#
#
#             <div id="c7e3cb53-2218-4214-9cc1-76f0e5c6d3bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c7e3cb53-2218-4214-9cc1-76f0e5c6d3bc")) {
#                     Plotly.newPlot(
#                         'c7e3cb53-2218-4214-9cc1-76f0e5c6d3bc',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "6d8183f9-79db-4e5e-ba72-a37f3e4b9682", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [69.8, 69.4, 69.1, 68.7, 68.3, 67.9, 67.4, 67.0, 66.5, 65.8, 65.0, 64.2, 63.3, 62.5, 61.7, 62.0]}],
# ...
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Uzbekistan
# <div>
#
#
#             <div id="d6961d44-0ca7-4be5-b459-b988348e40ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d6961d44-0ca7-4be5-b459-b988348e40ff")) {
#                     Plotly.newPlot(
#                         'd6961d44-0ca7-4be5-b459-b988348e40ff',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "5091867c-986c-4d58-8c5f-9eb833d8c1c0", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [72.0, 71.7, 71.6, 71.4, 71.2, 71.0, 78.0, 75.0, 73.0, 71.0, 69.9, 69.6, 69.4, 69.3, 69.1, 69.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d6961d44-0ca7-4be5-b459-b988348e40ff');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Vanuatu
# <div>
#
#
#             <div id="25e47acb-bf11-4b3a-8f84-79f9c40535dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("25e47acb-bf11-4b3a-8f84-79f9c40535dc")) {
#                     Plotly.newPlot(
#                         '25e47acb-bf11-4b3a-8f84-79f9c40535dc',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "f98c0671-5f8d-4fee-9a43-3314da468534", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [74.1, 73.9, 73.8, 73.7, 73.8, 73.7, 73.6, 73.2, 73.4, 73.6, 73.6, 73.3, 72.4, 73.1, 72.5, 72.5]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('25e47acb-bf11-4b3a-8f84-79f9c40535dc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Venezuela (Bolivarian Republic of)
# <div>
#
#
#             <div id="bf6c17d7-79fc-4ad2-83bd-5afaa09b190b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bf6c17d7-79fc-4ad2-83bd-5afaa09b190b")) {
#                     Plotly.newPlot(
#                         'bf6c17d7-79fc-4ad2-83bd-5afaa09b190b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "14d3b1e5-eefa-4c66-b86c-30e85f8ebb1f", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [76.0, 75.9, 75.7, 75.6, 75.4, 75.2, 75.0, 74.9, 74.7, 74.6, 74.4, 74.2, 74.0, 73.8, 73.6, 73.4]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bf6c17d7-79fc-4ad2-83bd-5afaa09b190b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Viet Nam
# <div>
#
#
#             <div id="85c349c9-199d-4eba-8279-27785861fa38" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("85c349c9-199d-4eba-8279-27785861fa38")) {
#                     Plotly.newPlot(
#                         '85c349c9-199d-4eba-8279-27785861fa38',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "1a68c749-95f6-4554-8d00-626a0e9030a3", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [65.7, 65.4, 65.4, 64.7, 64.6, 64.4, 64.1, 63.8, 63.4, 63.0, 62.6, 62.2, 61.9, 61.5, 61.1, 68.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('85c349c9-199d-4eba-8279-27785861fa38');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Yemen
# <div>
#
#
#             <div id="398c1ff5-e333-4c20-af75-16c22d3eab1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("398c1ff5-e333-4c20-af75-16c22d3eab1a")) {
#                     Plotly.newPlot(
#                         '398c1ff5-e333-4c20-af75-16c22d3eab1a',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "b9827ffe-eaad-4b97-8a35-803e72a91a79", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [61.8, 61.1, 63.0, 59.2, 58.2, 58.0, 57.4, 55.7, 52.6, 58.0, 49.3, 47.9, 46.4, 45.5, 44.6, 43.8]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('398c1ff5-e333-4c20-af75-16c22d3eab1a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Zambia
# <div>
#
#
#             <div id="bd98fa04-12d9-4314-bd98-4dc2a18012e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bd98fa04-12d9-4314-bd98-4dc2a18012e7")) {
#                     Plotly.newPlot(
#                         'bd98fa04-12d9-4314-bd98-4dc2a18012e7',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Life expectancy ", "text": "", "type": "scatter", "uid": "6015e88d-28e8-490b-95f8-545f261e1ebb", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [67.0, 59.2, 58.0, 56.6, 54.9, 52.4, 50.0, 48.2, 46.6, 45.4, 44.6, 44.3, 44.5, 44.8, 45.3, 46.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bd98fa04-12d9-4314-bd98-4dc2a18012e7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# Zimbabwe

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

countries = df['Country'].unique()
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111)

# X = 
for country in countries[:20]:
#     df_group.loc[country].iplot(y='Life expectancy ')
    df_group.loc[country].plot(y='Life expectancy ', ax=ax)

# %%
df['Life expectancy '].hist()

# %% [markdown]
# ### Displaying length of rows and columns in our dataset

# %%
df.shape
# Out:
# (2938, 22)

# %%
df[df.Country=="United States of America"].isna().sum()
# Out:
# Country                             0
# Year                                0
# Status                              0
# Life expectancy                     0
# Adult Mortality                     0
# infant deaths                       0
# Alcohol                             1
# percentage expenditure              0
# Hepatitis B                         0
# Measles                             0
#  BMI                                0
# under-five deaths                   0
# Polio                               0
# Total expenditure                   1
# Diphtheria                          0
#  HIV/AIDS                           0
# GDP                                16
# Population                         16
#  thinness  1-19 years               0
#  thinness 5-9 years                 0
# Income composition of resources    16
# Schooling                          16
# dtype: int64

# %%
len(df[df.Country=="United States of America"])
# Out:
# 16

# %%
df.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %% [markdown]
# ### Use profiling to speed up EDA

# %%
# profile = pandas_profiling.ProfileReport(df)

# %%
# from IPython.core.display import display, HTML
# display(HTML(profile.html))

# %% [markdown]
# ### Display column names and background research on column descriptions

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# `Status`
# Developed or Developing status
#
# `Life expectancy`
# Life Expectancy in age
#
# `Adult Mortality`
# Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
#
# `infant deaths`
# Number of Infant Deaths per 1000 population
#
# `Alcohol`
# Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
#
# `percentage expenditure`
# Expenditure on health as a percentage of Gross Domestic Product per capita(%)
#
# `Hepatitis B`
# Hepatitis B (HepB) immunization coverage among 1-year-olds (%)
#
# `Measles`
# Measles - number of reported cases per 1000 population
#
# `BMI`
# Average Body Mass Index of entire population
#
# `under-five deaths`
# Number of under-five deaths per 1000 population
#
# `Polio`
# Polio (Pol3) immunization coverage among 1-year-olds (%)
#
# `Total expenditure`
# General government expenditure on health as a percentage of total government expenditure (%)
#
# `Diphtheria`
# Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
#
# `HIV/AIDS`
# Deaths per 1 000 live births HIV/AIDS (0-4 years)
#
# `GDP`
# Gross Domestic Product per capita (in USD)
#
# `Population`
# Population of the country
#
# `thinness 1-19 years`
# Prevalence of thinness among children and adolescents for Age 10 to 19 (% )
#
# `thinness 5-9 years`
# Prevalence of thinness among children for Age 5 to 9(%)
#
# `Income composition of resources`
# Human Development Index in terms of income composition of resources (index ranging from 0 to 1) url: http://hdr.undp.org/en/content/human-development-index-hdi
#
# `Schooling`
# Number of years of Schooling(years)

# %% [markdown]
# ### Mapping life expectency for 2015

# %%
print('Maximum year is', df['Year'].max())
print('Minimum year is', df['Year'].min())
# Out:
# Maximum year is 2015
# Minimum year is 2000

# %% [markdown]
# Let's filter by 2015 to make a map of life expectency per country.

# %%
df_2015 = df[df['Year']==2015]

# %% [markdown]
# ### Reading in the country codes tsv to make the map (file generated from UN stats webpage:
# https://unstats.un.org/unsd/methodology/m49/

# %%
country_codes = pd.read_csv('country_code_2.tsv',sep='\t')
country_codes.head()
# Out:
#   Country or Area  M49 code ISO-alpha3 code
# 0     Afghanistan         4             AFG
# 1   Aland Islands       248             ALA
# 2         Albania         8             ALB
# 3         Algeria        12             DZA
# 4  American Samoa        16             ASM

# %% [markdown]
# ### Matching countries to country names in country codes tsv data

# %%
df_2015.replace("Côte d'Ivoire", "Cote d'Ivoire", inplace=True)
df_2015.replace('Swaziland', 'Eswatini', inplace=True)
df_2015.replace('The former Yugoslav republic of Macedonia', 'North Macedonia', inplace=True)

df_2015_map = df_2015.merge(country_codes, how="left", left_on="Country",right_on="Country or Area")
df_2015_map.rename(columns={'M49 code': 'id'}, inplace=True)
df_2015_map.drop(columns=['ISO-alpha3 code', 'Country or Area'], inplace=True)

df_2015_map['tooltip']=df_2015_map['Country']+': '+df_2015_map['Life expectancy '].astype(str) + ' yr'

# %% [markdown]
# ### Looking at the codes from geojson file (map feature) which defines border for all the countries.

# %%
# map_codes = [x['id'] for x in data.world_110m()['objects']['countries']['geometries']]
# map_codes

# %% [markdown]
# ### Making the map!

# %%
source = alt.topo_feature(data.world_110m.url,'countries')

plt = alt.Chart(source).mark_geoshape().encode(
    color=alt.Color('Life expectancy :Q', legend=alt.Legend(title='Years')),
    tooltip='tooltip:N'
).transform_lookup(
   lookup='id',
   from_=alt.LookupData(df_2015_map, 'id', ['Life expectancy ', 'tooltip'])
).project(
   type='equirectangular'
).properties(
    width=900,
    height=540,
    title=('Life Expectency in Years')
)

# %%
plt

# %% [markdown]
# ## Formulating the research question

# %% [markdown]
# **What are the most important feaures which contribute to life expectancy?**
#
# **How can we best predict life expectancy?**

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# ### Drop NaN's and check remaining length of dataframe

# %%
df_nona = df.dropna()

# %%
df_nona.shape
# Out:
# (1649, 22)

# %% [markdown]
# ### Rename Life expectancy column to target

# %%
df_nona.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df_nona.rename(columns={'Life expectancy ':'target'}, inplace=True)

# %%
df_nona.head()
# Out:
#        Country  Year      Status  target  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing    65.0            263.0             62
# 1  Afghanistan  2014  Developing    59.9            271.0             64
# 2  Afghanistan  2013  Developing    59.9            268.0             66
# 3  Afghanistan  2012  Developing    59.5            272.0             69
# 4  Afghanistan  2011  Developing    59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Make bootstrap with replacement to normalize the target column and find the true mean as a place to split the data at a certain age, and anything a above that age will be 1 for long life expectancy and 0 for low life expectancy.

# %%
age = []
for i in range(1000):
    x_age = np.random.choice(df_nona['target'],size=500)
    age.append(x_age.mean())
print(np.mean(age))
# Out:
# 69.3061334

# %%
df_nona['target'].describe()
# Out:
# count    1649.000000
# mean       69.302304
# std         8.796834
# min        44.000000
# 25%        64.400000
# 50%        71.700000
# 75%        75.000000
# max        89.000000
# Name: target, dtype: float64

# %%
median_age = np.median(df_nona['target'])
df_nona['target'] = df_nona.target.apply(lambda x: 1 if x >= median_age  else 0)

# %%
df_nona.head()
# Out:
#        Country  Year      Status  target  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing       0            263.0             62
# 1  Afghanistan  2014  Developing       0            271.0             64
# 2  Afghanistan  2013  Developing       0            268.0             66
# 3  Afghanistan  2012  Developing       0            272.0             69
# 4  Afghanistan  2011  Developing       0            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df_nona['Country'].nunique()
# Out:
# 133

# %%
count = 0 
for country in df_nona['Country'].unique() : 
    check = df_nona.loc[df_nona['Country']== country, 'target'].nunique()
    if (check == 1):
      
        count +=1
    else:
        print(country)
# Out:
# Azerbaijan
# Bangladesh
# Belarus
# Brazil
# Bulgaria
# Cabo Verde
# Colombia
# Dominican Republic
# El Salvador
# Guatemala
# Honduras
# Iraq
# Latvia
# Lithuania
# Maldives
# Mauritius
# Morocco
# Nicaragua
# Romania
# Russian Federation
# Samoa
# Sri Lanka
# Suriname
# Thailand
# Tonga
# Trinidad and Tobago
# Turkey
# Ukraine
# Vanuatu

# %%
count / df_nona['Country'].nunique()
# Out:
# 0.7819548872180451

# %%
#show that the model is able to generalize to different countries the model has not seen before

# %%
df_nona[df_nona['Country']=='Brazil']
# Out:
#     Country  Year      Status  target  Adult Mortality  infant deaths  \
# 353  Brazil  2014  Developing       1            144.0             44
# 354  Brazil  2013  Developing       1            146.0             46
# 355  Brazil  2012  Developing       1            148.0             49
# 356  Brazil  2011  Developing       1            152.0             51
# 357  Brazil  2010  Developing       1            154.0             54
# 358  Brazil  2009  Developing       1            157.0             57
# 359  Brazil  2008  Developing       1            158.0             61
# 360  Brazil  2007  Developing       1            159.0             65
# 361  Brazil  2006  Developing       1            161.0             70
# 362  Brazil  2005  Developing       1            163.0             75
# 363  Brazil  2004  Developing       1             17.0             81
# 364  Brazil  2003  Developing       1            172.0             88
# 365  Brazil  2002  Developing       0            176.0             95
# 366  Brazil  2001  Developing       0            179.0            103
# 367  Brazil  2000  Developing       1            183.0            111
#
#      Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 353     7.32               83.164654         96.0       876  ...   96.0
# 354     7.24              916.270845         96.0       220  ...   96.0
# 355     7.55              843.194626         96.0         2  ...   96.0
# 356     7.58             1084.999766         98.0        43  ...   98.0
# 357     7.52             1111.191325         96.0        68  ...   99.0
# 358     7.33              564.523390         99.0         0  ...   99.0
# 359     7.21              526.378064         96.0         0  ...   99.0
# 360     7.19              394.932130         99.0         0  ...   99.0
# 361     7.10               30.303747         99.0        57  ...   99.0
# 362     6.97               23.763701         98.0         6  ...   99.0
# 363     6.85              186.609049         96.0         0  ...   99.0
# 364     6.95               15.857812         97.0         2  ...   99.0
# 365     7.00              140.982477         92.0         1  ...   99.0
# 366     7.13              149.480209         91.0         1  ...   99.0
# 367     7.26              179.477729         94.0        36  ...   99.0
#
#      Total expenditure  Diphtheria    HIV/AIDS           GDP   Population  \
# 353               8.32         93.0        0.1   1226.617310   24213133.0
# 354               8.48         97.0        0.1  12216.944600    2248632.0
# 355               8.26         95.0        0.1  12291.466850     256983.0
# 356               8.90         99.0        0.1  13167.472890  198686688.0
# 357               8.27         99.0        0.1  11224.154800  196796269.0
# 358               8.65         99.0        0.1   8553.384700  194895996.0
# 359               8.24         99.0        0.1   8787.613750   19297929.0
# 360               8.28         99.0        0.1   7313.557962   19126637.0
# 361               8.36         99.0        0.1    586.145975   18912412.0
# 362               8.27         99.0        0.1    477.182746  186917361.0
# 363               7.70         99.0        0.1   3623.476670  184738458.0
# 364               6.94         99.0        0.1    359.587582  182482149.0
# 365               7.13         99.0        0.1   2819.649531    1815121.0
# 366               7.19         98.0        0.1   3146.951770    1777567.0
# 367               7.30         98.0        0.1   3739.119360  175287587.0
#
#       thinness  1-19 years   thinness 5-9 years  \
# 353                    2.7                  2.7
# 354                    2.8                  2.7
# 355                    2.8                  2.8
# 356                    2.9                  2.8
# 357                    2.9                  2.9
# 358                    3.0                  2.9
# 359                    3.0                  3.0
# 360                    3.1                  3.0
# 361                    3.1                  3.1
# 362                    3.2                  3.1
# 363                    3.2                  3.2
# 364                    3.3                  3.3
# 365                    3.3                  3.3
# 366                    3.4                  3.4
# 367                    3.4                  3.4
#
#      Income composition of resources  Schooling
# 353                            0.747       15.2
# 354                            0.734       14.2
# 355                            0.730       14.2
# 356                            0.724       14.0
# 357                            0.716       13.8
# 358                            0.714       13.8
# 359                            0.704       13.3
# 360                            0.700       13.5
# 361                            0.698       13.8
# 362                            0.694       13.8
# 363                            0.695       14.0
# 364                            0.699       14.8
# 365                            0.692       14.6
# 366                            0.685       14.3
# 367                            0.677       14.1
#
# [15 rows x 22 columns]

# %%
df_nona.target.value_counts()
# Out:
# 1    828
# 0    821
# Name: target, dtype: int64

# %%
#developed = 0, developing =1
#look into dropping one
df_nona = pd.concat([df_nona, pd.get_dummies(df_nona['Status'])], axis=1)
df_nona.head()
# Out:
#        Country  Year      Status  target  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing       0            263.0             62
# 1  Afghanistan  2014  Developing       0            271.0             64
# 2  Afghanistan  2013  Developing       0            268.0             66
# 3  Afghanistan  2012  Developing       0            272.0             69
# 4  Afghanistan  2011  Developing       0            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Diphtheria   \
# 0     0.01               71.279624         65.0      1154  ...         65.0
# 1     0.01               73.523582         62.0       492  ...         62.0
# 2     0.01               73.219243         64.0       430  ...         64.0
# 3     0.01               78.184215         67.0      2787  ...         67.0
# 4     0.01                7.097109         68.0      3013  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling  Developed  \
# 0                 17.3                            0.479       10.1          0
# 1                 17.5                            0.476       10.0          0
# 2                 17.7                            0.470        9.9          0
# 3                 18.0                            0.463        9.8          0
# 4                 18.2                            0.454        9.5          0
#
#    Developing
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 24 columns]

# %%
df_nona.drop(['Status'], axis=1, inplace=True)
df_nona.head()
# Out:
#        Country  Year  target  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015       0            263.0             62     0.01
# 1  Afghanistan  2014       0            271.0             64     0.01
# 2  Afghanistan  2013       0            268.0             66     0.01
# 3  Afghanistan  2012       0            272.0             69     0.01
# 4  Afghanistan  2011       0            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Diphtheria   \
# 0               71.279624         65.0      1154   19.1  ...         65.0
# 1               73.523582         62.0       492   18.6  ...         62.0
# 2               73.219243         64.0       430   18.1  ...         64.0
# 3               78.184215         67.0      2787   17.6  ...         67.0
# 4                7.097109         68.0      3013   17.2  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling  Developed  \
# 0                 17.3                            0.479       10.1          0
# 1                 17.5                            0.476       10.0          0
# 2                 17.7                            0.470        9.9          0
# 3                 18.0                            0.463        9.8          0
# 4                 18.2                            0.454        9.5          0
#
#    Developing
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Define X and y

# %%
from random import randint
all_countries = df.Country.unique()
# Choose random countries
num_to_withhold = 100
withhold_countries = set([])
while len(withhold_countries) < num_to_withhold:
    # Get a random integer so we can choose a random country
    withhold_countries.add(all_countries[randint(0, len(all_countries) - 1)])

withhold_countries = list(withhold_countries)
training_countries = [country for country in all_countries if (country not in withhold_countries)]


df_train = df_nona[df_nona['Country'].isin(training_countries)]
df_test = df_nona[df_nona['Country'].isin(withhold_countries)]

# %%
100/len(all_countries)
# Out:
# 0.5181347150259067

# %%
y = df_train['target']
X = df_train.drop(['target'], axis=1)

# %%
X.drop(['Country'], axis=1, inplace = True)

# %% [markdown]
# ### Split data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#Fit a model
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(fit_intercept = False, C = 1e12)
model_log = logreg.fit(X_train, y_train)
model_log
# Out:
# LogisticRegression(C=1000000000000.0, class_weight=None, dual=False,
#           fit_intercept=False, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
#Predict
y_hat_test = logreg.predict(X_test)
y_hat_train = logreg.predict(X_train)

# %%
#Accuracy of model matching training data
import numpy as np
#We could subtract the two columns. If values or equal, difference will be zero. Then count number of zeros.
residuals = np.abs(y_train - y_hat_train)
print(pd.Series(residuals).value_counts())
print(pd.Series(residuals).value_counts(normalize=True))
# Out:
# 0    455
# 1    173
# Name: target, dtype: int64
# 0    0.724522
# 1    0.275478
# Name: target, dtype: float64

# %%
#Accuracy of model matching test data
residuals = np.abs(y_test - y_hat_test)
print(pd.Series(residuals).value_counts())
print(pd.Series(residuals).value_counts(normalize=True))
# Out:
# 0    148
# 1     62
# Name: target, dtype: int64
# 0    0.704762
# 1    0.295238
# Name: target, dtype: float64

# %%
model_log.coef_
# Out:
# array([[-1.15502968e-04, -3.30733217e-05, -8.80908164e-06,
#          1.63494792e-07,  3.22477562e-05, -2.61039402e-06,
#         -8.82280511e-06,  7.39328681e-07, -1.34231756e-05,
#         -2.64452801e-06, -1.94743099e-07, -2.78808893e-06,
#         -7.55807653e-07,  2.16758801e-04, -6.66771406e-09,
#         -7.75465513e-07, -8.22399017e-07,  3.73707043e-09,
#         -1.46552162e-07,  3.32392781e-08, -9.07333266e-08]])

# %%
import statsmodels as sm
import sklearn.preprocessing as preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from scipy import stats

# %%
from patsy import dmatrices
y, X = dmatrices('Target ~ Age  + C(Race) + C(Sex)',
                  salaries, return_type = "dataframe")

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree 
classifier = DecisionTreeClassifier(random_state=10)  
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=10,
#             splitter='best')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc

acc = accuracy_score(y_test,y_pred) * 100
print("Accuracy is :{0}".format(acc))

# Check the AUC for predictions
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
print("\nAUC is :{0}".format(round(roc_auc,2)))

# Create and print a confusion matrix 
print('\nConfusion Matrix')
print('----------------')
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Accuracy is :91.2621359223301
#
# AUC is :0.91
#
# Confusion Matrix
# ----------------
# Predicted    0   1  All
# True
# 0          103   8  111
# 1           10  85   95
# All        113  93  206

# %%
# The model misclassified 33 rows

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

classifier.feature_importances_
def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(8,8))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")

plot_feature_importances(classifier)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-3ce5c9af6a58> in <module>
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3
# ----> 4 classifier.feature_importances_
#       5 def plot_feature_importances(model):
#       6     n_features = X_train.shape[1]
#
# NameError: name 'classifier' is not defined

# %% [markdown]
# The Income composition of resources which is the Human Development Index combines education, life expectency, and GNI index (economic factor).

# %% [markdown]
# ### Let's try Random Forrest but this time dropping Income composition of resources and Adult Mortality

# %%
y
X.drop(['Adult Mortality','Income composition of resources','Population','GDP','Year'], axis=1, inplace=True)

# %%
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
forest = RandomForestClassifier(n_estimators=100, max_depth= 5)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
forest.score(X_train, y_train)
# Out:
# 0.9577235772357724

# %%
forest.score(X_test, y_test)
# Out:
# 0.9271844660194175

# %%
plot_feature_importances(forest)

# %% [markdown]
# ### Grid search to optimize the random forest model

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [30, 100, 300],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [2, 4, 6]
}

# %%
gs = GridSearchCV(forest, param_grid, cv=5)
gs.fit(X_train, y_train)
gs.score(X_test, y_test)
gs.best_params_
# Out:
# {'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}

# %%
gs.score(X_test, y_test)
# Out:
# 0.912621359223301

# %%
gs.best_score_
# Out:
# 0.9040650406504065

# %%
forest2 = RandomForestClassifier(min_samples_split=2, min_samples_leaf=2, n_estimators=30, max_depth= 5)
forest2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
forest2.score(X_train, y_train)
# Out:
# 0.943089430894309

# %%
forest2.score(X_test, y_test)
# Out:
# 0.9077669902912622

# %%
plot_feature_importances(forest2)

# %% [markdown]
# ### Conclusions

# %% [markdown]
# School is an important factor in predicting whether people live long (> 71 years old) or not. Followed by AIDS and BMI. If this was a business such as a non-governmental organization trying to improve people's lives, then perhaps improving the healthcare system to lower mortality and make education available to all.

# %%
df_test.head()
# Out:
#        Country  Year  target  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015       0            263.0             62     0.01
# 1  Afghanistan  2014       0            271.0             64     0.01
# 2  Afghanistan  2013       0            268.0             66     0.01
# 3  Afghanistan  2012       0            272.0             69     0.01
# 4  Afghanistan  2011       0            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Diphtheria   \
# 0               71.279624         65.0      1154   19.1  ...         65.0
# 1               73.523582         62.0       492   18.6  ...         62.0
# 2               73.219243         64.0       430   18.1  ...         64.0
# 3               78.184215         67.0      2787   17.6  ...         67.0
# 4                7.097109         68.0      3013   17.2  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling  Developed  \
# 0                 17.3                            0.479       10.1          0
# 1                 17.5                            0.476       10.0          0
# 2                 17.7                            0.470        9.9          0
# 3                 18.0                            0.463        9.8          0
# 4                 18.2                            0.454        9.5          0
#
#    Developing
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 23 columns]

# %%
y_test_2 = df_test['target']

X_test_2 = df_test.drop(['Country', 'target','Adult Mortality','Income composition of resources','Population','GDP','Year'], axis=1)
y_pred_2 = forest2.predict(X_test_2)

acc = accuracy_score(y_test_2,y_pred_2) * 100
print("Accuracy is :{0}".format(acc))

# Check the AUC for predictions
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_2, y_pred_2)
roc_auc = auc(false_positive_rate, true_positive_rate)
print("\nAUC is :{0}".format(round(roc_auc,2)))

# Create and print a confusion matrix 
print('\nConfusion Matrix')
print('----------------')
pd.crosstab(y_test_2, y_pred_2, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Accuracy is :85.74879227053141
#
# AUC is :0.85
#
# Confusion Matrix
# ----------------
# Predicted    0    1  All
# True
# 0          305   95  400
# 1           23  405  428
# All        328  500  828

# %% [markdown]
# It's 88% accurate on countries it is never seen before when 70 countries (36%) were completely withheld from training.
#
# When we increased the number to 100 countries (trained on the remaining), the accuracy dropped to 85%

# %%
num_to_withhold
# Out:
# 100
